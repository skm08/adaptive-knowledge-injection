# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path(
    "F:/Study Abroad/Publications/Three-Paper Strategy/Paper B/Source Code/adaptive-knowledge-injection"
)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.utils.config import load_config

cfg = load_config(
    PROJECT_ROOT / "configs" / "datasets.yaml"
)

print(cfg.seed)

print(cfg.datasets.pubmedqa.hf_dataset)

print(cfg.datasets.pubmedqa.task)

print(cfg.datasets.cnn_dailymail.domain)
# Out:
# 42
# qiaojin/PubMedQA
# question_answering
# news

# %% [markdown]
# # Logger.py Testing

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("F:/Study Abroad/Publications/Three-Paper Strategy/Paper B/Source Code/adaptive-knowledge-injection")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.utils.logger import get_logger, banner, section

logger = get_logger("Downloader")

banner(logger, "DATA DOWNLOAD")

logger.info("Starting download...")

section(logger, "STEP 1")

logger.info("Loading PubMedQA")

logger.info("Loading SciQ")

logger.warning("This is a warning.")

logger.error("This is only a test error.")
# Out:
# [2026-06-26 23:11:59] [INFO    ] [Downloader] ======================================================================
# [2026-06-26 23:11:59] [INFO    ] [Downloader] Logger initialized
# [2026-06-26 23:11:59] [INFO    ] [Downloader] Logger Name : Downloader
# [2026-06-26 23:11:59] [INFO    ] [Downloader] Log File    : outputs\logs\Downloader_20260626_231159.log
# [2026-06-26 23:11:59] [INFO    ] [Downloader] ======================================================================
# [2026-06-26 23:11:59] [INFO    ] [Downloader] ======================================================================
# [2026-06-26 23:11:59] [INFO    ] [Downloader] DATA DOWNLOAD
# [2026-06-26 23:11:59] [INFO    ] [Downloader] ======================================================================
# [2026-06-26 23:11:59] [INFO    ] [Downloader] Starting download...
# [2026-06-26 23:11:59] [INFO    ] [Downloader]
# ...
